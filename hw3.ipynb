# %%
import pandas as pd
import json
import os

# %%
data = []
with open('data/pubs_test.json') as f:
    data = json.load(f)

# %%
def get_co_author(data_it):
    authors = []
    for author in data_it['authors']:
        authors.append(author['name'].replace(' ', '').replace('-', ''))
    return ' '.join(authors)

# %%
def get_keyword(data_it):
    keywords = []
    return data_it['keywords']

# %%
def generate_output_one_set(labels, data, size):
    print('generate output')
    output_set = []
    i = 0
    while i < size:
        output_set.append([])
        i += 1
    i = 0
    for it in labels:
        if (it != -1):
            output_set[it].append(data[i]['id'])
        i += 1
    return output_set

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import DBSCAN
from sklearn import metrics
import numpy as np

global_result = {}
for set_d in data:
    print(set_d)
    vectorizer = TfidfVectorizer()
    docs = []
    for it in data[set_d]:
        docs.append(get_co_author(it))
    X = vectorizer.fit_transform(docs)
    #print(vectorizer.get_feature_names())
    db = DBSCAN(eps=0.6, min_samples=3, metric="cosine").fit(X)
    ##
    core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
    core_samples_mask[db.core_sample_indices_] = True
    labels = db.labels_

    n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
    n_noise_ = list(labels).count(-1)
    print('cluster OK:', n_clusters_)
    print('cluster noise:', n_noise_)
    
    output_set = generate_output_one_set(labels, data[set_d], n_clusters_)
    global_result[set_d] = output_set
# Out:
# qian_liu
# cluster OK: 161
# cluster noise: 808
# generate output
# shuang_li
# cluster OK: 114
# cluster noise: 463
# generate output
# shuai_wang
# cluster OK: 118
# cluster noise: 608
# generate output
# meng_liu
# cluster OK: 56
# cluster noise: 336
# generate output
# qing_wang
# cluster OK: 225
# cluster noise: 1209
# generate output
# t_suzuki
# cluster OK: 14
# cluster noise: 55
# generate output
# peng_chen
# cluster OK: 166
# cluster noise: 887
# generate output
# m_liu
# cluster OK: 11
# cluster noise: 91
# generate output
# peng_zhao
# cluster OK: 110
# cluster noise: 599
# generate output
# n_li
# cluster OK: 5
# cluster noise: 144
# generate output
# qin_zhang
# cluster OK: 122
# cluster noise: 656
# generate output
# min_wu
# cluster OK: 115
# cluster noise: 593
# generate output
# meng_wang
# cluster OK: 169
# cluster noise: 973
# generate output
# peng_gao
# cluster OK: 122
# cluster noise: 519
# generate output
# q_liu
# cluster OK: 9
# cluster noise: 146
# generate output
# m_zhang
# cluster OK: 6
# cluster noise: 121
# generate output
# qiang_liu
# cluster OK: 247
# cluster noise: 1228
# generate output
# nan_li
# cluster OK: 200
# cluster noise: 916
# generate output
# r_zhang
# cluster OK: 4
# cluster noise: 84
# generate output
# rui_li
# cluster OK: 228
# cluster noise: 1167
# generate output

# %%
json.dumps(global_result)
# Out:
# '{"qian_liu": [["5bc6bfdd486cef66309b8553", "5bc6bfdd486cef66309dfeb3", "5bc6bfdd486cef66309e810b", "5bc6bfdd486cef66309e4aa8", "5bc6bfdd486cef66309d52dc", "5bc6bfdd486cef66309c1a8f", "5bc6bfdd486cef66309f0218", "5bc6bfdd486cef66309e8e24", "5bc6bfdd486cef66309ca7df", "5bc6bfdd486cef66309bab2a", "5bc6bfdd486cef66309abfae", "5bc6bfdd486cef66309d9a6d", "5bc6bfdd486cef66309d36c3", "5bc6bfdd486cef66309af8aa", "5bc6bfdd486cef66309aa37b", "5bc6bfdd486cef66309f0709", "5bc6bfdd486cef66309de4f7", "5bc6bfdd486cef66309c457c", "5bc6bfdd486cef66309bbffa", "5bc6bfdd486cef66309c4b32", "5bc6bfdd486cef66309d7295", "5bc6bfdd486cef66309bded6", "5bc6bfdd486cef66309c2350", "5bc6bfdd486cef66309c3a2b", "5bc6bfdd486cef66309c8cf7", "5bc6bfdd486cef66309e0f35", "5bc6bfdd486cef66309b3307", "5bc6bfdd486cef66309e403f", "5bc6bfdd486cef66309e34f0", "5bc6bfdd486cef66309c8400", "5bc6bfdd486cef66309c23d5", "5bc6bfdd486cef66309f08f1", "5bc6bfdd486cef66309c63c1", "5bc6bfdd486cef66309b0d7a", "5bc6bfdd486cef66309e703b", "5bc6bfdd486cef66309d4516", "5bc6bfdd486cef66309bb304", "5bc6bfdd486cef66309e46d2", "5bc6bfdd486cef66309eb61f", "5bc6bfdd486cef66309ddc9e", "5bc6bfdd486cef66309c3bc1", "5bc6bfdd486cef66309b4ce6", "5bc6bfdd486cef66309aa4ef", "5bc6bfdd486cef66309dc908", "5bc6bfdd486cef66309e482e", "5bc6bfdd486cef66309b334f", "5bc6bfdd486cef66309b18b1", "5bc6bfdd486cef66309cbc50", "5bc6bfdd486cef66309d8b45", "5bc6bfdd486cef66309e790f", "5bc6bfdd486cef66309c97fb", "5bc6bfdd486cef66309eb66f", "5bc6bfdd486cef66309b1c6c", "5bc6bfdd486cef66309e70fd", "5bc6bfdd486cef66309ac5df", "5bc6bfdd486cef66309b0679", "5bc6bfdd486cef66309c7e75", "5bc6bfdd486cef66309c3d58", "5bc6bfdd486cef66309ccc28", "5bc6bfdd486cef66309e7912", "5bc6bfdd486cef66309ec5a7", "5bc6bfdd486cef66309ae550", "5bc6bfdd486cef66309e3049", "5bc6bfdd486cef66309c2ec7", "5bc6bfdd486cef66309d8db6", "5bc6bfdd486cef66309e4f35", "5bc6bfdd486cef66309cd19e", "5bc6bfdd486cef66309f0aa4", "5bc6bfdd486cef66309b8f18", "5bc6bfdd486cef66309c6b91", "5bc6bfdd486cef66309dde63", "5bc6bfdd486cef66309d4934", "5bc6bfdd486cef66309e02fe", "5bc6bfdd486cef66309ed350", "5bc6bfdd486cef66309d1783", "5bc6bfdd486cef66309e671d", "5bc6bfdd486cef66309b4cb7", "5bc6bfdd486cef66309c1d44", "5bc6bfdd486cef66309ae9f1", "5bc6bfdd486cef66309d226f", "5bc6bfdd486cef66309d0fce", "5bc6bfdd486cef66309c75f5", "5bc6bfdd486cef66309db62e", "5bc6bfdd486cef66309c7ef8", "5bc6bfdd486cef66309b1792", "5bc6bfdd486cef66309d219a", "5bc6bfdd486cef66309ede19", "5bc6bfdd486cef66309c4bb2", "5bc6bfdd486cef66309e05d0", "5bc6bfdd486cef66309c21d6", "5bc6bfdd486cef66309d9c61", "5bc6bfdd486cef66309d6cf6", "5bc6bfdd486cef66309b2cf3", "5bc6bfdd486cef66309caeac", "5bc6bfdd486cef66309e6731", "5bc6bfdd486cef66309b3624", "5bc6bfdd486cef66309cdb45", "5bc6bfdd486cef66309dce05", "5bc6bfdd486cef66309c5733", "5bc6bfdd486cef66309dbcd6", "5bc6bfdd486cef66309f0400", "5bc6bfdd486cef66309d042d", "5bc6bfdd486cef66309beaf4", "5bc6bfdd486cef66309e2d95", "5bc6bfdd486cef66309e5eda", "5bc6bfdd486cef66309b59d9", "5bc6bfdd486cef66309ada55", "5bc6bfdd486cef66309b77a7", "5bc6bfdd486cef66309c9cb2", "5bc6bfdd486cef66309c54b2", "5bc6bfdd486cef66309d9ef9", "5bc6bfdd486cef66309ac3fa", "5bc6bfdd486cef66309cfa71", "5bc6bfdd486cef66309e02c7", "5bc6bfdd486cef66309d8f6d", "5bc6bfdd486cef66309c7616", "5bc6bfdd486cef66309e49ba"], ["5bc6bfdd486cef66309b776c", "5bc6bfdd486cef66309b726c", "5bc6bfdd486cef66309b95e1", "5bc6bfdd486cef66309c565d", "5bc6bfdd486cef66309e90d4"], ["5bc6bfdd486cef66309e98c0", "5bc6bfde486cef66309f0fde", "5bc6bfdd486cef66309bf0e1", "5bc6bfdd486cef66309ca1db", "5bc6bfdd486cef66309d7fb5", "5bc6bfdd486cef66309c859d", "5bc6bfdd486cef66309c1943", "5bc6bfdd486cef66309b4b3f", "5bc6bfdd486cef66309c38a0", "5bc6bfdd486cef66309b1edd", "5bc6bfdd486cef66309b46ea", "5bc6bfdd486cef66309c34d8", "5bc6bfdd486cef66309d5234", "5bc6bfdd486cef66309b5e21", "5bc6bfdd486cef66309b5ca3", "5bc6bfdd486cef66309c2cea", "5bc6bfdd486cef66309e6ab7", "5bc6bfdd486cef66309cb6a8", "5bc6bfdd486cef66309ccdae", "5bc6bfdd486cef66309c5c79", "5bc ...

# %%
with open('result.json', 'w') as of:
    json.dump(global_result, of)
